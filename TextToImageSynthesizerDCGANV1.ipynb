# %% [markdown]
# **Mounting The Drive To Load Data And Store Models**

# %%
# # Load the Drive helper and mount
# from google.colab import drive
# drive.mount('/content/drive')
# %cd  /content/drive/'My Drive'/TTI/

# %%
# !pip install torchvision
# !pip install tqdm
# !pip install h5py
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torchvision in ./.local/lib/python3.8/site-packages (0.11.1)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /share/apps/python/3.8.6/intel/lib/python3.8/site-packages (from torchvision) (8.0.1)
# Requirement already satisfied: torch==1.10.0 in ./.local/lib/python3.8/site-packages (from torchvision) (1.10.0)
# Requirement already satisfied: numpy in /share/apps/python/3.8.6/intel/lib/python3.8/site-packages/numpy-1.19.2-py3.8-linux-x86_64.egg (from torchvision) (1.19.2)
# Requirement already satisfied: typing-extensions in ./.local/lib/python3.8/site-packages (from torch==1.10.0->torchvision) (4.0.1)
# WARNING: You are using pip version 20.2.3; however, version 21.3.1 is available.
# You should consider upgrading via the '/share/apps/python/3.8.6/intel/bin/python -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tqdm in ./.local/lib/python3.8/site-packages (4.62.3)
# WARNING: You are using pip version 20.2.3; however, version 21.3.1 is available.
# You should consider upgrading via the '/share/apps/python/3.8.6/intel/bin/python -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: h5py in ./.local/lib/python3.8/site-packages (3.6.0)
# Requirement already satisfied: numpy>=1.14.5 in /share/apps/python/3.8.6/intel/lib/python3.8/site-packages/numpy-1.19.2-py3.8-linux-x86_64.egg (from h5py) (1.19.2)
# WARNING: You are using pip version 20.2.3; however, version 21.3.1 is available.
# You should consider upgrading via the '/share/apps/python/3.8.6/intel/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# **Importing All The Necessary Libraries**

# %%
import torch
import torchvision
import numpy as np
from torch import nn
from tqdm.auto import tqdm
from torchvision import transforms
from torchvision.utils import make_grid
import matplotlib.pyplot as plt
import torch.nn.functional as F
from torchvision.datasets import ImageFolder
from __future__ import print_function
import argparse
import os
import random
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data
import torchvision.datasets as dset
import torchvision.transforms as transforms
import torchvision.utils as vutils
import matplotlib.animation as animation
from IPython.display import HTML
from torch.autograd import Variable
import pdb
import io
from torch.utils.data import Dataset, DataLoader
import h5py
from PIL import Image
import yaml
ngpu = 2
device = torch.device("cuda:0" if (torch.cuda.is_available() and ngpu > 0) else "cpu")
# %matplotlib inline

# %% [markdown]
# **Generator Model Class**

# %%
def make_gen_block(input_channels, output_channels, kernel_size=2, stride=1, pad = 0, final_layer=False):
    if not final_layer:
        return nn.Sequential(
            nn.ConvTranspose2d(input_channels, output_channels, kernel_size, stride, pad, bias = False),
            nn.BatchNorm2d(output_channels),
            nn.ReLU(inplace=True)
        )
    else: # Final Layer
        return nn.Sequential(
            nn.ConvTranspose2d(input_channels, output_channels, kernel_size, stride, pad, bias = False),
            nn.Tanh()
        )
class Generator(nn.Module):
    def __init__(self):
      super(Generator, self).__init__()
      self.img_size = 64
      self.nc = 3
      self.noise_dim = 100
      self.ngf = 64
      self.embed_dim = 1024
      self.projected_embed_dim = 128
      self.latent_dim = self.noise_dim + self.projected_embed_dim
      self.generator = nn.Sequential(
        make_gen_block(self.latent_dim, self.ngf*8, 4, 1, 0),
        make_gen_block(self.ngf*8, self.ngf*4, 4, 2, 1),
        make_gen_block(self.ngf*4, self.ngf*2, 4, 2, 1),
        make_gen_block(self.ngf*2, self.ngf, 4, 2, 1),
        make_gen_block(self.ngf, self.nc, 4, 2, 1, True),
        )
      
      self.projection = nn.Sequential(
			  nn.Linear(in_features=self.embed_dim, out_features=self.projected_embed_dim),
			  nn.BatchNorm1d(num_features=self.projected_embed_dim),
			  nn.LeakyReLU(negative_slope=0.2, inplace=True)
			  )
      
    def forward(self, embed_vector, z):
      projected_embed = self.projection(embed_vector).unsqueeze(2).unsqueeze(3)
      latent_vector = torch.cat([projected_embed, z], 1)
      output = self.generator(latent_vector)
      return output

# %% [markdown]
# **Testing And Printing Generator Model**

# %%
def build_gm():
  gmodel = Generator()
  print(gmodel)
  return gmodel
build_gm();
# Out:
# Generator(
#   (generator): Sequential(
#     (0): Sequential(
#       (0): ConvTranspose2d(228, 512, kernel_size=(4, 4), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (2): Sequential(
#       (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (3): Sequential(
#       (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (4): Sequential(
#       (0): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): Tanh()
#     )
#   )
#   (projection): Sequential(
#     (0): Linear(in_features=1024, out_features=128, bias=True)
#     (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
# )

# %% [markdown]
# **Discriminator Model Class**

# %%
class Concat_embed(nn.Module):

    def __init__(self, embed_dim, projected_embed_dim):
        super(Concat_embed, self).__init__()
        self.projection = nn.Sequential(
            nn.Linear(in_features=embed_dim, out_features=projected_embed_dim),
            nn.BatchNorm1d(num_features=projected_embed_dim),
            nn.LeakyReLU(negative_slope=0.2, inplace=True)
            )

    def forward(self, inp, embed):
        projected_embed = self.projection(embed)
        replicated_embed = projected_embed.repeat(4, 4, 1, 1).permute(2,  3, 0, 1)
        hidden_concat = torch.cat([inp, replicated_embed], 1)
        return hidden_concat

def make_disc_block(input_channels, output_channels, kernel_size=4, stride=2, pad = 1, first_layer=False):
        if not first_layer:
            return nn.Sequential(
                nn.Conv2d(input_channels, output_channels, kernel_size, stride, pad),
                nn.BatchNorm2d(output_channels),
                nn.LeakyReLU(0.2, inplace=True)
            )
        else:
            return nn.Sequential(
                nn.Conv2d(input_channels, output_channels, kernel_size, stride, pad),
                nn.LeakyReLU(0.2, inplace=True)
            )

class Discriminator(nn.Module):
  def __init__(self):
    super(Discriminator, self).__init__()
    self.img_size = 64
    self.nc = 3
    self.noise_dim = 100
    self.ndf = 64
    self.embed_dim = 1024
    self.projected_embed_dim = 128
    self.b_dim = 128
    self.c_dim = 64

    self.discriminator1 = nn.Sequential(
        make_disc_block(self.nc, self.ndf, 4, 2, 1, True),
        make_disc_block(self.ndf, self.ndf*2, 4, 2, 1),
        make_disc_block(self.ndf*2, self.ndf*4, 4, 2, 1),
        make_disc_block(self.ndf*4, self.ndf*8, 4, 2, 1),
        )
    self.projector = Concat_embed(self.embed_dim, self.projected_embed_dim)
    self.discriminator2 = nn.Sequential(
        nn.Conv2d(self.ndf*8 + self.projected_embed_dim, 1, 4, 1, 0, bias = False),
        nn.Sigmoid()
    )

  def forward(self, input, embed):
    x_1 = self.discriminator1(input)
    x = self.projector(x_1, embed)
    output = self.discriminator2(x)
    return output.view(-1, 1).squeeze(1), x_1

# %% [markdown]
# **Testing And Printing Discriminator Model**

# %%
def build_dm():
  dmodel = Discriminator()
  print(dmodel)
  return dmodel
build_dm();
# Out:
# Discriminator(
#   (discriminator1): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (2): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (3): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#   )
#   (projector): Concat_embed(
#     (projection): Sequential(
#       (0): Linear(in_features=1024, out_features=128, bias=True)
#       (1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#   )
#   (discriminator2): Sequential(
#     (0): Conv2d(640, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (1): Sigmoid()
#   )
# )

# %% [markdown]
# **Helper Class to Handle and Transform Input Data**

# %%
class Text2ImageDataset(Dataset):

    def __init__(self, datasetFile, transform=None, split=0):
        self.datasetFile = datasetFile
        self.transform = transform
        self.dataset = None
        self.dataset_keys = None
        self.split = 'train' if split == 0 else 'valid' if split == 1 else 'test'
        self.h5py2int = lambda x: int(np.array(x))

    def __len__(self):
        f = h5py.File(self.datasetFile, 'r')
        self.dataset_keys = [str(k) for k in f[self.split].keys()]
        length = len(f[self.split])
        f.close()

        return length

    def __getitem__(self, idx):
        if self.dataset is None:
            self.dataset = h5py.File(self.datasetFile, mode='r')
            self.dataset_keys = [str(k) for k in self.dataset[self.split].keys()]

        example_name = self.dataset_keys[idx]
        example = self.dataset[self.split][example_name]

        right_image = bytes(np.array(example['img']))
        right_embed = np.array(example['embeddings'], dtype=float)
        wrong_image = bytes(np.array(self.find_wrong_image(example['class'])))
        inter_embed = np.array(self.find_inter_embed())

        right_image = Image.open(io.BytesIO(right_image)).resize((64, 64))
        wrong_image = Image.open(io.BytesIO(wrong_image)).resize((64, 64))

        right_image = self.validate_image(right_image)
        wrong_image = self.validate_image(wrong_image)

        txt = np.array(example['txt']).astype(str)

        sample = {
                'right_images': torch.FloatTensor(right_image),
                'right_embed': torch.FloatTensor(right_embed),
                'wrong_images': torch.FloatTensor(wrong_image),
                'inter_embed': torch.FloatTensor(inter_embed),
                'txt': str(txt)
                 }

        sample['right_images'] = sample['right_images'].sub_(127.5).div_(127.5)
        sample['wrong_images'] =sample['wrong_images'].sub_(127.5).div_(127.5)

        return sample

    def find_wrong_image(self, category):
        idx = np.random.randint(len(self.dataset_keys))
        example_name = self.dataset_keys[idx]
        example = self.dataset[self.split][example_name]
        _category = example['class']

        if _category != category:
            return example['img']

        return self.find_wrong_image(category)

    def find_inter_embed(self):
        idx = np.random.randint(len(self.dataset_keys))
        example_name = self.dataset_keys[idx]
        example = self.dataset[self.split][example_name]
        return example['embeddings']


    def validate_image(self, img):
        img = np.array(img, dtype=float)
        if len(img.shape) < 3:
            rgb = np.empty((64, 64, 3), dtype=np.float32)
            rgb[:, :, 0] = img
            rgb[:, :, 1] = img
            rgb[:, :, 2] = img
            img = rgb

        return img.transpose(2, 0, 1)

# %% [markdown]
# **Utility Class to Initialize And Save Model**

# %%
class Utils(object):

    @staticmethod
    def smooth_label(tensor, offset):
        return tensor + offset

    @staticmethod
    def save_checkpoint(discriminator, generator, dir_path, subdir_path, epoch):
        path =  os.path.join(dir_path, subdir_path)
        if not os.path.exists(path):
            os.makedirs(path)

        torch.save(discriminator.state_dict(), '{0}/disc_{1}.pth'.format(path, epoch))
        torch.save(generator.state_dict(), '{0}/gen_{1}.pth'.format(path, epoch))

    @staticmethod
    def weights_init(m):
        classname = m.__class__.__name__
        if classname.find('Conv') != -1:
            m.weight.data.normal_(0.0, 0.02)
        elif classname.find('BatchNorm') != -1:
            m.weight.data.normal_(1.0, 0.02)
            m.bias.data.fill_(0)

# %% [markdown]
# **Reading Input Data/Splitting Data**

# %%
traindata = Text2ImageDataset('flowers.hdf5', split=0)
traindata_loader = DataLoader(traindata, batch_size=64, shuffle=True,
                        num_workers=2)
valdata = Text2ImageDataset('flowers.hdf5', split=1)
valdata_loader = DataLoader(valdata, batch_size=64, shuffle=True,
                        num_workers=2)
testdata = Text2ImageDataset('flowers.hdf5', split=2)
testdata_loader = DataLoader(testdata, batch_size=64, shuffle=True,
                        num_workers=2)

# %%
print(len(traindata))
# Out:
# 29390

# %% [markdown]
# **Visualizing Input Dataset**

# %%
real_batch = next(iter(traindata_loader))
plt.figure(figsize=(8,8))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch['right_images'].to(device)[:64], padding=2, normalize=True).cpu(),(1,2,0)))

# %% [markdown]
# **Helper Class For Plotting And Logging**

# %%
class Helper(object):
  @staticmethod
  def fakePlotter(img_list):
    plt.subplot(1,2,2)
    plt.axis("off")
    plt.title("Fake Images")
    plt.imshow(np.transpose(img_list[-1].cpu().numpy(),(1,2,0)))
    plt.show()

  @staticmethod    
  def iteration_log(epoch, discriminator_loss, generator_loss, real_score, fake_score):
        print("Epoch: %d, discriminator_loss= %f, generator_loss= %f, D(X)= %f, D(G(X))= %f" % (epoch, discriminator_loss.data.cpu().mean(), generator_loss.data.cpu().mean(), real_score.data.cpu().mean(),fake_score.data.cpu().mean()))

# %% [markdown]
# **Loss Functions for Generator and Discriminator**

# %%
class generator_loss(torch.nn.Module):
    def __init__(self):
        super(generator_loss, self).__init__()
        self.estimator = nn.BCELoss()

    def forward(self, fake):
        batch_size = fake.size()[0]
        self.labels = Variable(torch.FloatTensor(batch_size).cuda().fill_(1))
        return self.estimator(fake, self.labels)

class discriminator_loss(torch.nn.Module):
    def __init__(self):
        super(discriminator_loss, self).__init__()
        self.estimator = nn.BCELoss()

    def forward(self, real, wrong, fake):
        batch_size = real.size()[0]
        self.real_labels = Variable(torch.FloatTensor(batch_size).cuda().fill_(1))
        self.fake_labels = Variable(torch.FloatTensor(batch_size).cuda().fill_(0))
        return self.estimator(real, self.real_labels) + 0.5 * (self.estimator(wrong, self.fake_labels) + self.estimator(fake, self.fake_labels))

# %% [markdown]
# **Main DCGAN Class**

# %%
class DCGAN(object):
    def __init__(self, learning_rate, batch_size=64, epochs=1, pre_trained_gen=None, pre_trained_disc=None):

        self.generator = torch.nn.DataParallel(Generator().cuda())
        self.generator.apply(Utils.weights_init)
        self.discriminator = torch.nn.DataParallel(Discriminator().cuda())
        self.discriminator.apply(Utils.weights_init)

        self.noise_dim = 100
        self.l1_coef = 50
        self.l2_coef = 100
        self.beta1 = 0.5

        self.batch_size = batch_size
        self.learning_rate = learning_rate
        self.num_epochs = epochs
        self.traindata_loader = traindata_loader
        self.valdata_loader = valdata_loader
        self.testdata_loader = testdata_loader

        self.optimize_discriminator = torch.optim.Adam(self.discriminator.parameters(), lr=self.learning_rate, betas=(self.beta1, 0.999))
        self.optimize_generator = torch.optim.Adam(self.generator.parameters(), lr=self.learning_rate, betas=(self.beta1, 0.999))

        self.checkpoints_path = 'TrainingFinal/checkpoints'
        self.train_save_path = 'TrainingFinal/res'
        self.val_save_path = 'ValidationFinal/valres'
        self.test_save_path = 'TestingFinal/testres'

    def train_dcgan(self):
        criterion = nn.BCELoss()
        l2_loss = nn.MSELoss()
        l1_loss = nn.L1Loss()
        print("Running..................")
        for epoch in range(self.num_epochs):
            img_list = []
            iteration = 0
            for sample in self.traindata_loader:
                Iterations.append(iteration)
                EpochsLib.append(epoch)
                iteration = iteration + 1
                right_images = sample['right_images']
                right_embed = sample['right_embed']
                wrong_images = sample['wrong_images']

                right_images = Variable(right_images.float()).cuda()
                right_embed = Variable(right_embed.float()).cuda()
                wrong_images = Variable(wrong_images.float()).cuda()

                real_labels = torch.ones(right_images.size(0))
                fake_labels = torch.zeros(right_images.size(0))

                smoothed_real_labels = torch.FloatTensor(Utils.smooth_label(real_labels.numpy(), -0.1))

                real_labels = Variable(real_labels).cuda()
                smoothed_real_labels = Variable(smoothed_real_labels).cuda()
                fake_labels = Variable(fake_labels).cuda()

                # Train the discriminator model
                self.discriminator.zero_grad()
                outputs, activation_real = self.discriminator(right_images, right_embed)
                real_loss = criterion(outputs, smoothed_real_labels)
                real_score = outputs

                noise = Variable(torch.randn(right_images.size(0), 100)).cuda()
                noise = noise.view(noise.size(0), 100, 1, 1)
                fake_images = self.generator(right_embed, noise)
                outputs, _ = self.discriminator(fake_images, right_embed)
                fake_loss = criterion(outputs, fake_labels)
                fake_score = outputs

                discriminator_loss = real_loss + fake_loss

                discriminator_loss.backward()
                self.optimize_discriminator.step()

                # Train the generator model
                self.generator.zero_grad()
                noise = Variable(torch.randn(right_images.size(0), 100)).cuda()
                noise = noise.view(noise.size(0), 100, 1, 1)
                fake_images = self.generator(right_embed, noise)
                outputs, activation_fake = self.discriminator(fake_images, right_embed)
                _, activation_real = self.discriminator(right_images, right_embed)

                activation_fake = torch.mean(activation_fake, 0)
                activation_real = torch.mean(activation_real, 0)

                generator_loss = criterion(outputs, real_labels) + self.l2_coef * l2_loss(activation_fake, activation_real.detach()) + self.l1_coef * l1_loss(fake_images, right_images)

                generator_loss.backward()
                self.optimize_generator.step()
                if (iteration%100)==0:
                    Helper.iteration_log(epoch,discriminator_loss, generator_loss, real_score, fake_score)
                img_list.append(vutils.make_grid(fake_images, padding=2, normalize=True))
                Generator_losses.append(generator_loss.data.cpu().mean().item())
                Discriminator_losses.append(discriminator_loss.data.cpu().mean().item())
                Real_scores.append(real_score.data.cpu().mean().item())
                Fake_scores.append(fake_score.data.cpu().mean().item())
            #Helper.fakePlotter(img_list)
            #print("Done: ", epoch)
            Utils.save_checkpoint(self.discriminator, self.generator, self.checkpoints_path, '', epoch)
        print("Done..................")

    def train_predict(self):
        criterion = nn.BCELoss()
        l2_loss = nn.MSELoss()
        l1_loss = nn.L1Loss()
        for sample in self.traindata_loader:
            right_images = sample['right_images']
            right_embed = sample['right_embed']
            txt = sample['txt']
            real_labels = torch.ones(right_images.size(0))
            real_labels = Variable(real_labels).cuda()
            if not os.path.exists('resultsfinal/{0}'.format(self.train_save_path)):
                os.makedirs('resultsfinal/{0}'.format(self.train_save_path))

            right_images = Variable(right_images.float()).cuda()
            right_embed = Variable(right_embed.float()).cuda()

            noise = Variable(torch.randn(right_images.size(0), 100)).cuda()
            noise = noise.view(noise.size(0), 100, 1, 1)
            fake_images = self.generator(right_embed, noise)
            outputs, activation_fake = self.discriminator(fake_images, right_embed)
            _, activation_real = self.discriminator(right_images, right_embed)
            activation_fake = torch.mean(activation_fake, 0)
            activation_real = torch.mean(activation_real, 0)

            generator_loss = criterion(outputs, real_labels) + self.l2_coef * l2_loss(activation_fake, activation_real.detach()) + self.l1_coef * l1_loss(fake_images, right_images)
            print("generator_loss= %f" % (generator_loss.data.cpu().mean()))
            i=0
            for image, t in zip(fake_images, txt):
                im = Image.fromarray(image.data.mul_(127.5).add_(127.5).byte().permute(1, 2, 0).cpu().numpy())
                print('i = ', i)
                if i==0:
                  plt.imshow(im)
                  plt.show()
                i = i+1
                try:
                  im.save('resultsfinal/{0}/{1}.jpg'.format(self.train_save_path, t.replace("/", "").replace(".\n", "").replace(" ", "")[:100]))
                except:
                  print('')
                print(t)
            break
    
    def val_predict(self):
        criterion = nn.BCELoss()
        l2_loss = nn.MSELoss()
        l1_loss = nn.L1Loss()
        for sample in self.valdata_loader:
            right_images = sample['right_images']
            right_embed = sample['right_embed']
            txt = sample['txt']
            real_labels = torch.ones(right_images.size(0))
            real_labels = Variable(real_labels).cuda()
            if not os.path.exists('resultsfinal/{0}'.format(self.val_save_path)):
                os.makedirs('resultsfinal/{0}'.format(self.val_save_path))

            right_images = Variable(right_images.float()).cuda()
            right_embed = Variable(right_embed.float()).cuda()

            noise = Variable(torch.randn(right_images.size(0), 100)).cuda()
            noise = noise.view(noise.size(0), 100, 1, 1)
            fake_images = self.generator(right_embed, noise)
            outputs, activation_fake = self.discriminator(fake_images, right_embed)
            _, activation_real = self.discriminator(right_images, right_embed)
            activation_fake = torch.mean(activation_fake, 0)
            activation_real = torch.mean(activation_real, 0)

            generator_loss = criterion(outputs, real_labels) + self.l2_coef * l2_loss(activation_fake, activation_real.detach()) + self.l1_coef * l1_loss(fake_images, right_images)
            print("generator_loss= %f" % (generator_loss.data.cpu().mean()))
            i=0
            for image, t in zip(fake_images, txt):
                im = Image.fromarray(image.data.mul_(127.5).add_(127.5).byte().permute(1, 2, 0).cpu().numpy())
                print('i = ', i)
                if i==0:
                  plt.imshow(im)
                  plt.show()
                i = i+1
                try:
                  im.save('resultsfinal/{0}/{1}.jpg'.format(self.val_save_path, t.replace("/", "").replace(".\n", "").replace(" ", "")[:100]))
                except:
                  print('')
                print(t)
            break

    def test_predict(self):
        criterion = nn.BCELoss()
        l2_loss = nn.MSELoss()
        l1_loss = nn.L1Loss()
        for sample in self.testdata_loader:
            right_images = sample['right_images']
            right_embed = sample['right_embed']
            txt = sample['txt']
            real_labels = torch.ones(right_images.size(0))
            real_labels = Variable(real_labels).cuda()
            if not os.path.exists('resultsfinal/{0}'.format(self.test_save_path)):
                os.makedirs('resultsfinal/{0}'.format(self.test_save_path))

            right_images = Variable(right_images.float()).cuda()
            right_embed = Variable(right_embed.float()).cuda()

            noise = Variable(torch.randn(right_images.size(0), 100)).cuda()
            noise = noise.view(noise.size(0), 100, 1, 1)
            fake_images = self.generator(right_embed, noise)
            outputs, activation_fake = self.discriminator(fake_images, right_embed)
            _, activation_real = self.discriminator(right_images, right_embed)
            activation_fake = torch.mean(activation_fake, 0)
            activation_real = torch.mean(activation_real, 0)

            generator_loss = criterion(outputs, real_labels) + self.l2_coef * l2_loss(activation_fake, activation_real.detach()) + self.l1_coef * l1_loss(fake_images, right_images)
            print("generator_loss= %f" % (generator_loss.data.cpu().mean()))
            i=0
            for image, t in zip(fake_images, txt):
                im = Image.fromarray(image.data.mul_(127.5).add_(127.5).byte().permute(1, 2, 0).cpu().numpy())
                print('i = ', i)
                if i==0:
                  plt.imshow(im)
                  plt.show()
                i = i+1
                try:
                  im.save('resultsfinal/{0}/{1}.jpg'.format(self.test_save_path, t.replace("/", "").replace(".\n", "").replace(" ", "")[:100]))
                except:
                  print('')
                print(t)
            break

# %% [markdown]
# **DCGAN Trainer**

# %%
Generator_losses = []
Discriminator_losses = []
Real_scores = []
Fake_scores = []
Iterations = []
EpochsLib = []
dcganmodel = DCGAN(0.0002, 64, 100, None, None)
dcganmodel.train_dcgan()
# Out:
# Running..................
# Epoch: 0, discriminator_loss= 0.926458, generator_loss= 30.051638, D(X)= 0.489665, D(G(X))= 0.010374
# Epoch: 0, discriminator_loss= 0.822953, generator_loss= 30.859934, D(X)= 0.864027, D(G(X))= 0.334136
# Epoch: 0, discriminator_loss= 1.757864, generator_loss= 27.363636, D(X)= 0.221440, D(G(X))= 0.053255
# Epoch: 0, discriminator_loss= 0.878053, generator_loss= 25.801941, D(X)= 0.570554, D(G(X))= 0.179992
# Epoch: 1, discriminator_loss= 1.158907, generator_loss= 25.500395, D(X)= 0.573388, D(G(X))= 0.362980
# Epoch: 1, discriminator_loss= 1.070584, generator_loss= 26.501074, D(X)= 0.599430, D(G(X))= 0.346262
# Epoch: 1, discriminator_loss= 1.028569, generator_loss= 27.753212, D(X)= 0.829477, D(G(X))= 0.464582
# Epoch: 1, discriminator_loss= 1.362666, generator_loss= 23.948124, D(X)= 0.317224, D(G(X))= 0.145175
# Epoch: 2, discriminator_loss= 1.892136, generator_loss= 26.718769, D(X)= 0.166548, D(G(X))= 0.027774
# Epoch: 2, discriminator_loss= 1.223711, generator_loss= 24.427198, D(X)= 0.545596, D(G(X))= 0.376976
# Epoch: 2, discriminator_loss= 0.838084, generator_loss= 27.302986, D(X)= 0.596338, D(G(X))= 0.190427
# Epoch: 2, discriminator_loss= 0.926652, generator_loss= 26.288948, D(X)= 0.548993, D(G(X))= 0.216030
# Epoch: 3, discriminator_loss= 0.848219, generator_loss= 27.457636, D(X)= 0.558332, D(G(X))= 0.165542
# Epoch: 3, discriminator_loss= 0.830314, generator_loss= 27.541637, D(X)= 0.855968, D(G(X))= 0.358564
# Epoch: 3, discriminator_loss= 0.698572, generator_loss= 27.030201, D(X)= 0.727083, D(G(X))= 0.202479
# Epoch: 3, discriminator_loss= 1.270439, generator_loss= 28.348343, D(X)= 0.906068, D(G(X))= 0.568063
# Epoch: 4, discriminator_loss= 1.060786, generator_loss= 26.127094, D(X)= 0.395341, D(G(X))= 0.070630
# Epoch: 4, discriminator_loss= 1.005526, generator_loss= 24.107384, D(X)= 0.480751, D(G(X))= 0.182837
# Epoch: 4, discriminator_loss= 0.881206, generator_loss= 26.976448, D(X)= 0.694128, D(G(X))= 0.309612
# Epoch: 4, discriminator_loss= 0.627633, generator_loss= 26.785536, D(X)= 0.664853, D(G(X))= 0.103262
# Epoch: 5, discriminator_loss= 0.843237, generator_loss= 25.441246, D(X)= 0.489661, D(G(X))= 0.056928
# Epoch: 5, discriminator_loss= 0.805086, generator_loss= 25.685532, D(X)= 0.792007, D(G(X))= 0.310069
# Epoch: 5, discriminator_loss= 0.724529, generator_loss= 27.497721, D(X)= 0.824997, D(G(X))= 0.274581
# Epoch: 5, discriminator_loss= 0.740040, generator_loss= 27.606550, D(X)= 0.801521, D(G(X))= 0.270944
# Epoch: 6, discriminator_loss= 0.840766, generator_loss= 27.243443, D(X)= 0.867944, D(G(X))= 0.361021
# Epoch: 6, discriminator_loss= 1.863270, generator_loss= 25.359392, D(X)= 0.163040, D(G(X))= 0.043529
# Epoch: 6, discriminator_loss= 0.897870, generator_loss= 25.409101, D(X)= 0.626338, D(G(X))= 0.273727
# Epoch: 6, discriminator_loss= 0.812632, generator_loss= 26.679869, D(X)= 0.791353, D(G(X))= 0.298973
# Epoch: 7, discriminator_loss= 0.763244, generator_loss= 28.104097, D(X)= 0.798085, D(G(X))= 0.285618
# Epoch: 7, discriminator_loss= 1.063580, generator_loss= 27.645882, D(X)= 0.860925, D(G(X))= 0.457128
# Epoch: 7, discriminator_loss= 0.832351, generator_loss= 25.460735, D(X)= 0.506029, D(G(X))= 0.077555
# Epoch: 7, discriminator_loss= 0.773707, generator_loss= 26.121265, D(X)= 0.768795, D(G(X))= 0.279395
# Epoch: 8, discriminator_loss= 0.886018, generator_loss= 26.023777, D(X)= 0.827654, D(G(X))= 0.366706
# Epoch: 8, discriminator_loss= 0.730398, generator_loss= 26.664577, D(X)= 0.644699, D(G(X))= 0.136959
# Epoch: 8, discriminator_loss= 0.812374, generator_loss= 26.894508, D(X)= 0.616982, D(G(X))= 0.173555
# Epoch: 8, discriminator_loss= 0.993023, generator_loss= 28.547119, D(X)= 0.913365, D(G(X))= 0.435946
# Epoch: 9, discriminator_loss= 0.662676, generator_loss= 25.802906, D(X)= 0.781462, D(G(X))= 0.212384
# Epoch: 9, discriminator_loss= 0.683276, generator_loss= 28.021767, D(X)= 0.824333, D(G(X))= 0.242849
# Epoch: 9, discriminator_loss= 0.900739, generator_loss= 25.847857, D(X)= 0.872363, D(G(X))= 0.366037
# Epoch: 9, discriminator_loss= 0.673314, generator_loss= 25.956703, D(X)= 0.764759, D(G(X))= 0.213200
# Epoch: 10, discriminator_loss= 0.637082, generator_loss= 27.960939, D(X)= 0.850099, D(G(X))= 0.217997
# Epoch: 10, discriminator_loss= 0.922541, generator_loss= 24.922079, D(X)= 0.492374, D(G(X))= 0.107934
# Epoch: 10, discriminator_loss= 0.661834, generator_loss= 25.405188, D(X)= 0.671524, D(G(X))= 0.123494
# Epoch: 10, discriminator_loss= 0.821955, generator_loss= 27.030113, D(X)= 0.867019, D(G(X))= 0.336473
# Epoch: 11, discriminator_loss= 0.677090, generator_loss= 28.018244, D(X)= 0.638439, D(G(X))= 0.067032
# Epoch: 11, discriminator_loss= 0.849574, generator_loss= 27.402149, D(X)= 0.824355, D(G(X))= 0.329636
# Epoch: 11, discriminator_loss= 0.650799, generator_loss= 27.178469, D(X)= 0.756094, D(G(X))= 0.163079
# Epoch: 11, discriminator_loss= 0.621598, generator_loss= 25.911037, D(X)= 0.760137, D(G(X))= 0.155276
# Epoch: 12, discriminator_loss= 1.117188, generator_loss= 28.821732, D(X)= 0.962271, D(G(X))= 0.438184
# Epoch: 12, discriminator_loss= 0.624288, generator_loss= 25.646048, D(X)= 0.739664, D(G(X))= 0.126498
# Epoch: 12, discriminator_loss= 1.031600, generator_loss= 25.204395, D(X)= 0.443006, D(G(X))= 0.073812
# Epoch: 12, discriminator_loss= 0.684088, generator_loss= 26.918051, D(X)= 0.844218, D(G(X))= 0.239312
# Epoch: 13, discriminator_loss= 0.923555, generator_loss= 28.231596, D(X)= 0.943847, D(G(X))= 0.379327
# Epoch: 13, discriminator_loss= 1.267706, generator_loss= 28.323650, D(X)= 0.973263, D(G(X))= 0.510830
# Epoch: 13, discriminator_loss= 0.842498, generator_loss= 27.784433, D(X)= 0.852024, D(G(X))= 0.330284
# Epoch: 13, discriminator_loss= 0.750695, generator_loss= 28.469673, D(X)= 0.942711, D(G(X))= 0.283280
# Epoch: 14, discriminator_loss= 0.578477, generator_loss= 26.150267, D(X)= 0.768722, D(G(X))= 0.099854
# Epoch: 14, discriminator_loss= 0.530379, generator_loss= 28.600582, D(X)= 0.904274, D(G(X))= 0.149615
# Epoch: 14, discriminator_loss= 0.468822, generator_loss= 27.768074, D(X)= 0.895683, D(G(X))= 0.103199
# Epoch: 14, discriminator_loss= 0.697658, generator_loss= 24.784052, D(X)= 0.637694, D(G(X))= 0.126566
# Epoch: 15, discriminator_loss= 0.535204, generator_loss= 28.712524, D(X)= 0.819732, D(G(X))= 0.125546
# Epoch: 15, discriminator_loss= 0.486990, generator_loss= 26.788378, D(X)= 0.823082, D(G(X))= 0.086376
# Epoch: 15, discriminator_loss= 0.835541, generator_loss= 26.022964, D(X)= 0.491448, D(G(X))= 0.020160
# Epoch: 15, discriminator_loss= 0.474338, generator_loss= 26.671045, D(X)= 0.817031, D(G(X))= 0.079145
# Epoch: 16, discriminator_loss= 0.593180, generator_loss= 27.053585, D(X)= 0.834412, D(G(X))= 0.174500
# Epoch: 16, discriminator_loss= 0.519543, generator_loss= 25.621372, D(X)= 0.753214, D(G(X))= 0.065934
# Epoch: 16, discriminator_loss= 0.432320, generator_loss= 29.676533, D(X)= 0.812467, D(G(X))= 0.023127
# Epoch: 16, discriminator_loss= 0.707168, generator_loss= 27.537243, D(X)= 0.902870, D(G(X))= 0.242640
# Epoch: 17, discriminator_loss= 0.652501, generator_loss= 26.786180, D(X)= 0.630379, D(G(X))= 0.045695
# Epoch: 17, discriminator_loss= 0.558775, generator_loss= 27.280613, D(X)= 0.719079, D(G(X))= 0.078706
# Epoch: 17, discriminator_loss= 0.889036, generator_loss= 25.287642, D(X)= 0.469418, D(G(X))= 0.036751
# Epoch: 17, discriminator_loss= 0.536781, generator_loss= 27.625788, D(X)= 0.906025, D(G(X))= 0.138253
# Epoch: 18, discriminator_loss= 0.460885, generator_loss= 26.879454, D(X)= 0.787467, D(G(X))= 0.039226
# Epoch: 18, discriminator_loss= 0.474422, generator_loss= 27.289619, D(X)= 0.883718, D(G(X))= 0.092298
# Epoch: 18, discriminator_loss= 0.491753, generator_loss= 26.845081, D(X)= 0.819168, D(G(X))= 0.094563
# Epoch: 18, discriminator_loss= 0.554171, generator_loss= 26.443760, D(X)= 0.689990, D(G(X))= 0.053308
# Epoch: 19, discriminator_loss= 0.598982, generator_loss= 27.872824, D(X)= 0.920612, D(G(X))= 0.172676
# Epoch: 19, discriminator_loss= 0.627512, generator_loss= 24.776436, D(X)= 0.689846, D(G(X))= 0.090074
# Epoch: 19, discriminator_loss= 0.556797, generator_loss= 25.109768, D(X)= 0.704028, D(G(X))= 0.051737
# Epoch: 19, discriminator_loss= 0.566162, generator_loss= 27.236460, D(X)= 0.909007, D(G(X))= 0.171794
# Epoch: 20, discriminator_loss= 0.420954, generator_loss= 27.860777, D(X)= 0.857578, D(G(X))= 0.045810
# Epoch: 20, discriminator_loss= 0.423783, generator_loss= 29.248596, D(X)= 0.842109, D(G(X))= 0.030710
# Epoch: 20, discriminator_loss= 0.528928, generator_loss= 26.626616, D(X)= 0.725143, D(G(X))= 0.027174
# Epoch: 20, discriminator_loss= 0.486177, generator_loss= 27.021080, D(X)= 0.840412, D(G(X))= 0.093072
# Epoch: 21, discriminator_loss= 0.481660, generator_loss= 28.875732, D(X)= 0.922899, D(G(X))= 0.096492
# Epoch: 21, discriminator_loss= 0.486300, generator_loss= 29.254374, D(X)= 0.898448, D(G(X))= 0.097808
# Epoch: 21, discriminator_loss= 0.470395, generator_loss= 27.700127, D(X)= 0.765337, D(G(X))= 0.038528
# Epoch: 21, discriminator_loss= 0.448166, generator_loss= 27.937160, D(X)= 0.810741, D(G(X))= 0.045566
# Epoch: 22, discriminator_loss= 0.421138, generator_loss= 28.487629, D(X)= 0.849884, D(G(X))= 0.044298
# Epoch: 22, discriminator_loss= 0.455911, generator_loss= 26.663200, D(X)= 0.783371, D(G(X))= 0.035743
# Epoch: 22, discriminator_loss= 0.482832, generator_loss= 27.759392, D(X)= 0.907646, D(G(X))= 0.106308
# Epoch: 22, discriminator_loss= 0.471140, generator_loss= 28.689461, D(X)= 0.929376, D(G(X))= 0.081893
# Epoch: 23, discriminator_loss= 0.493491, generator_loss= 26.982080, D(X)= 0.890657, D(G(X))= 0.110795
# Epoch: 23, discriminator_loss= 0.439640, generator_loss= 28.176964, D(X)= 0.866753, D(G(X))= 0.068413
# Epoch: 23, discriminator_loss= 0.462788, generator_loss= 29.129421, D(X)= 0.911712, D(G(X))= 0.083656
# Epoch: 23, discriminator_loss= 0.513589, generator_loss= 28.321169, D(X)= 0.930095, D(G(X))= 0.113461
# Epoch: 24, discriminator_loss= 0.463008, generator_loss= 28.373520, D(X)= 0.868127, D(G(X))= 0.080428
# Epoch: 24, discriminator_loss= 0.442636, generator_loss= 27.937229, D(X)= 0.855130, D(G(X))= 0.051987
# Epoch: 24, discriminator_loss= 0.485515, generator_loss= 28.119350, D(X)= 0.924693, D(G(X))= 0.063954
# Epoch: 24, discriminator_loss= 0.424077, generator_loss= 27.134762, D(X)= 0.840112, D(G(X))= 0.032452
# Epoch: 25, discriminator_loss= 0.478623, generator_loss= 26.971199, D(X)= 0.805504, D(G(X))= 0.058733
# Epoch: 25, discriminator_loss= 0.430971, generator_loss= 26.993456, D(X)= 0.805411, D(G(X))= 0.037784
# Epoch: 25, discriminator_loss= 0.514595, generator_loss= 27.078369, D(X)= 0.905999, D(G(X))= 0.136454
# Epoch: 25, discriminator_loss= 0.475545, generator_loss= 27.444283, D(X)= 0.756236, D(G(X))= 0.037147
# Epoch: 26, discriminator_loss= 0.507252, generator_loss= 27.032686, D(X)= 0.882408, D(G(X))= 0.119765
# Epoch: 26, discriminator_loss= 0.443332, generator_loss= 27.809975, D(X)= 0.862242, D(G(X))= 0.041568
# Epoch: 26, discriminator_loss= 0.419045, generator_loss= 28.701170, D(X)= 0.815207, D(G(X))= 0.010891
# Epoch: 26, discriminator_loss= 0.476889, generator_loss= 27.005518, D(X)= 0.787505, D(G(X))= 0.039264
# Epoch: 27, discriminator_loss= 0.425537, generator_loss= 26.953005, D(X)= 0.833113, D(G(X))= 0.030123
# Epoch: 27, discriminator_loss= 0.439968, generator_loss= 26.892765, D(X)= 0.822042, D(G(X))= 0.024636
# Epoch: 27, discriminator_loss= 0.801092, generator_loss= 22.944866, D(X)= 0.540095, D(G(X))= 0.022426
# Epoch: 27, discriminator_loss= 0.412457, generator_loss= 28.659016, D(X)= 0.816919, D(G(X))= 0.018661
# Epoch: 28, discriminator_loss= 0.590538, generator_loss= 28.961105, D(X)= 0.975906, D(G(X))= 0.105449
# Epoch: 28, discriminator_loss= 0.459034, generator_loss= 26.833452, D(X)= 0.835092, D(G(X))= 0.048812
# Epoch: 28, discriminator_loss= 0.424955, generator_loss= 27.833168, D(X)= 0.935536, D(G(X))= 0.048569
# Epoch: 28, discriminator_loss= 0.438949, generator_loss= 29.529312, D(X)= 0.891477, D(G(X))= 0.047373
# Epoch: 29, discriminator_loss= 0.434339, generator_loss= 27.971886, D(X)= 0.913074, D(G(X))= 0.034467
# Epoch: 29, discriminator_loss= 0.532314, generator_loss= 28.377796, D(X)= 0.953017, D(G(X))= 0.126444
# Epoch: 29, discriminator_loss= 0.550413, generator_loss= 28.052271, D(X)= 0.964057, D(G(X))= 0.113329
# Epoch: 29, discriminator_loss= 0.446422, generator_loss= 26.735899, D(X)= 0.796902, D(G(X))= 0.037972
# Epoch: 30, discriminator_loss= 0.466791, generator_loss= 29.358162, D(X)= 0.950266, D(G(X))= 0.067551
# Epoch: 30, discriminator_loss= 0.463180, generator_loss= 28.354399, D(X)= 0.937639, D(G(X))= 0.070632
# Epoch: 30, discriminator_loss= 0.434678, generator_loss= 30.008633, D(X)= 0.814489, D(G(X))= 0.015433
# Epoch: 30, discriminator_loss= 0.492915, generator_loss= 27.886196, D(X)= 0.941448, D(G(X))= 0.070364
# Epoch: 31, discriminator_loss= 0.418107, generator_loss= 27.767143, D(X)= 0.868625, D(G(X))= 0.040308
# Epoch: 31, discriminator_loss= 0.563632, generator_loss= 27.657207, D(X)= 0.913200, D(G(X))= 0.156080
# Epoch: 31, discriminator_loss= 0.432748, generator_loss= 29.079721, D(X)= 0.914028, D(G(X))= 0.061208
# Epoch: 31, discriminator_loss= 0.449084, generator_loss= 29.072578, D(X)= 0.966211, D(G(X))= 0.029581
# Epoch: 32, discriminator_loss= 0.404170, generator_loss= 27.847464, D(X)= 0.853212, D(G(X))= 0.031004
# Epoch: 32, discriminator_loss= 0.395868, generator_loss= 27.760117, D(X)= 0.887086, D(G(X))= 0.027161
# Epoch: 32, discriminator_loss= 0.455727, generator_loss= 28.602585, D(X)= 0.786898, D(G(X))= 0.011037
# Epoch: 32, discriminator_loss= 0.449150, generator_loss= 28.458954, D(X)= 0.943253, D(G(X))= 0.048156
# Epoch: 33, discriminator_loss= 0.452786, generator_loss= 26.390507, D(X)= 0.905100, D(G(X))= 0.067947
# Epoch: 33, discriminator_loss= 0.448233, generator_loss= 27.372093, D(X)= 0.920406, D(G(X))= 0.062801
# Epoch: 33, discriminator_loss= 0.405663, generator_loss= 28.532066, D(X)= 0.849506, D(G(X))= 0.022878
# Epoch: 33, discriminator_loss= 0.413120, generator_loss= 29.675707, D(X)= 0.921506, D(G(X))= 0.020840
# Epoch: 34, discriminator_loss= 0.499696, generator_loss= 26.735081, D(X)= 0.900648, D(G(X))= 0.077600
# Epoch: 34, discriminator_loss= 0.404738, generator_loss= 27.210423, D(X)= 0.860917, D(G(X))= 0.023683
# Epoch: 34, discriminator_loss= 0.439604, generator_loss= 28.772125, D(X)= 0.944624, D(G(X))= 0.057105
# Epoch: 34, discriminator_loss= 0.493059, generator_loss= 28.337673, D(X)= 0.945875, D(G(X))= 0.086921
# Epoch: 35, discriminator_loss= 0.462261, generator_loss= 27.867439, D(X)= 0.901770, D(G(X))= 0.059143
# Epoch: 35, discriminator_loss= 0.406959, generator_loss= 28.145742, D(X)= 0.908185, D(G(X))= 0.031230
# Epoch: 35, discriminator_loss= 0.390525, generator_loss= 28.934381, D(X)= 0.869706, D(G(X))= 0.016791
# Epoch: 35, discriminator_loss= 0.477793, generator_loss= 25.613834, D(X)= 0.759474, D(G(X))= 0.030880
# Epoch: 36, discriminator_loss= 0.457438, generator_loss= 27.303288, D(X)= 0.761807, D(G(X))= 0.009274
# Epoch: 36, discriminator_loss= 0.424098, generator_loss= 27.299370, D(X)= 0.817027, D(G(X))= 0.021419
# Epoch: 36, discriminator_loss= 0.601064, generator_loss= 29.564999, D(X)= 0.976417, D(G(X))= 0.114726
# Epoch: 36, discriminator_loss= 0.439146, generator_loss= 28.191549, D(X)= 0.847965, D(G(X))= 0.027223
# Epoch: 37, discriminator_loss= 0.403961, generator_loss= 26.867346, D(X)= 0.832418, D(G(X))= 0.020490
# Epoch: 37, discriminator_loss= 0.476251, generator_loss= 27.161186, D(X)= 0.790178, D(G(X))= 0.037968
# Epoch: 37, discriminator_loss= 0.465080, generator_loss= 27.525307, D(X)= 0.741459, D(G(X))= 0.016374
# Epoch: 37, discriminator_loss= 0.500087, generator_loss= 28.168470, D(X)= 0.960269, D(G(X))= 0.086159
# Epoch: 38, discriminator_loss= 0.434457, generator_loss= 26.574490, D(X)= 0.865613, D(G(X))= 0.054708
# Epoch: 38, discriminator_loss= 0.413775, generator_loss= 26.778324, D(X)= 0.870306, D(G(X))= 0.042401
# Epoch: 38, discriminator_loss= 0.488950, generator_loss= 29.102749, D(X)= 0.963059, D(G(X))= 0.058879
# Epoch: 38, discriminator_loss= 0.459250, generator_loss= 28.973602, D(X)= 0.960145, D(G(X))= 0.053109
# Epoch: 39, discriminator_loss= 0.418311, generator_loss= 27.064997, D(X)= 0.794331, D(G(X))= 0.010069
# Epoch: 39, discriminator_loss= 0.395213, generator_loss= 29.266705, D(X)= 0.926491, D(G(X))= 0.027859
# Epoch: 39, discriminator_loss= 0.416762, generator_loss= 27.605970, D(X)= 0.866537, D(G(X))= 0.028835
# Epoch: 39, discriminator_loss= 0.415142, generator_loss= 28.142738, D(X)= 0.888768, D(G(X))= 0.039884
# Epoch: 40, discriminator_loss= 0.437075, generator_loss= 28.706278, D(X)= 0.857972, D(G(X))= 0.027566
# Epoch: 40, discriminator_loss= 0.454645, generator_loss= 26.303543, D(X)= 0.833676, D(G(X))= 0.036723
# Epoch: 40, discriminator_loss= 0.422025, generator_loss= 27.318516, D(X)= 0.804098, D(G(X))= 0.012166
# Epoch: 40, discriminator_loss= 0.410935, generator_loss= 27.766277, D(X)= 0.947742, D(G(X))= 0.033610
# Epoch: 41, discriminator_loss= 0.421074, generator_loss= 27.376392, D(X)= 0.828462, D(G(X))= 0.018315
# Epoch: 41, discriminator_loss= 0.417414, generator_loss= 27.308653, D(X)= 0.810310, D(G(X))= 0.011732
# Epoch: 41, discriminator_loss= 0.436412, generator_loss= 27.796200, D(X)= 0.919076, D(G(X))= 0.060738
# Epoch: 41, discriminator_loss= 0.408668, generator_loss= 26.970520, D(X)= 0.888021, D(G(X))= 0.027222
# Epoch: 42, discriminator_loss= 0.492160, generator_loss= 26.922478, D(X)= 0.954171, D(G(X))= 0.084140
# Epoch: 42, discriminator_loss= 0.445788, generator_loss= 28.423826, D(X)= 0.900604, D(G(X))= 0.047906
# Epoch: 42, discriminator_loss= 0.401746, generator_loss= 27.760675, D(X)= 0.867710, D(G(X))= 0.021573
# Epoch: 42, discriminator_loss= 0.443010, generator_loss= 26.996994, D(X)= 0.770145, D(G(X))= 0.009882
# Epoch: 43, discriminator_loss= 0.456668, generator_loss= 30.074261, D(X)= 0.952576, D(G(X))= 0.037824

# %% [markdown]
# **DCGAN Tester On Training Data**

# %%
dcganmodel.train_predict()

# %% [markdown]
# **DCGAN Tester On Validation Data**

# %%
dcganmodel.val_predict()

# %% [markdown]
# **DCGAN Tester On Testing Data**

# %%
dcganmodel.test_predict()

# %% [markdown]
# **Plotting Results Of Generated Images From Test Data**

# %%
dataroot = "resultsfinal/TestingFinal/"
plotdataset = dset.ImageFolder(root=dataroot,
                           transform=transforms.Compose([
                               transforms.Resize(64),
                               transforms.CenterCrop(64),
                               transforms.ToTensor(),
                               transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                           ]))
dataloader = torch.utils.data.DataLoader(plotdataset, batch_size=64,
                                         shuffle=True, num_workers=4)

real_batch = next(iter(dataloader))
plt.figure(figsize=(8,8))
plt.axis("off")
plt.title("Fake Generated Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch[0].to(device)[:64], padding=2, normalize=True).cpu(),(1,2,0)))

# %% [markdown]
# **Plotting Generator And Discriminator Losses and Scores During Training**

# %%
plt.figure(figsize=(10,5))
plt.title("Generator, Discriminator Loss During Training")
plt.plot(Generator_losses,label="G")
plt.plot(Discriminator_losses,label="D")
plt.xlabel("iterations")
plt.ylabel("Loss")
plt.legend()
plt.show()

plt.figure(figsize=(10,5))
plt.title("Discriminator Real, Fake Scores During Training")
plt.plot(Real_scores,label="R")
plt.plot(Fake_scores,label="F")
plt.xlabel("iterations")
plt.ylabel("Scores")
plt.legend()
plt.show()

# %% [markdown]
# **Saving Losses To CSV For Future Analysis**

# %%
import pickle
import pandas as pd

outfile = 'epoch_loss_final.csv'

output_file = open(outfile, "w")
dataframe_dict = {"Epoch" : [], "Iteration": [], "GeneratorLoss": [], "DiscriminatorLoss": [], "RealScore": [], "FakeScore": []}

for i in range(0, len(Iterations)):
    dataframe_dict['Epoch'].append(EpochsLib[i])
    dataframe_dict['Iteration'].append(Iterations[i])
    dataframe_dict['GeneratorLoss'].append(Generator_losses[i])
    dataframe_dict['DiscriminatorLoss'].append(Discriminator_losses[i])
    dataframe_dict['RealScore'].append(Real_scores[i])
    dataframe_dict['FakeScore'].append(Fake_scores[i])

df = pd.DataFrame(data=dataframe_dict)
df.to_csv(outfile, index=False)
print("Written to csv file {}".format(outfile))
